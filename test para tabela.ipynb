# %%
import pandas as pd

def get_zr2_data():
    return {
        'Usos Habitacionais Permitidos': {
            'Habitação Unifamiliar': {
                'COEFICIENTE DE APROVEITAMENTO': 1,
                'ALTURA (pavimentos)': 2,
                'PORTE (m²)': None,
                'TAXA DE OCUPAÇÃO MÁXIMA': 0.5,
                'RECUO (m)': 5,
                'TAXA DE PERMEABILIDADE MÍNIMA': 0.25,
                'AFASTAMENTO DAS DIVISAS MÍNIMO (m)': None,
                'LOTE PADRÃO (testada x área)': '12x360',
                'OBSERVACOES': [
                    "Deverá ser obedecida a fração de terreno de no mínimo 120 m² por unidade habitacional.\nTaxa de ocupação: No caso da área do lote for inferior ao padrão de zoneamento, será admitida taxa de ocupação superior a 50% até o limite de 60%, calculada proporcionalmente à área do lote, exclusivamente para uma habitação unifamiliar.\nTaxa de permeabilidade: Atender regulação específica"
                ]
            },
            'Habitação Unifamiliar em Série': {
                'COEFICIENTE DE APROVEITAMENTO': 1,
                'ALTURA (pavimentos)': 2,
                'PORTE (m²)': None,
                'TAXA DE OCUPAÇÃO MÁXIMA': 0.5,
                'RECUO (m)': 5,
                'TAXA DE PERMEABILIDADE MÍNIMA': 0.25,
                'AFASTAMENTO DAS DIVISAS MÍNIMO (m)': None,
                'LOTE PADRÃO (testada x área)': '12x360',
                'OBSERVACOES': [
                    "Deverá ser obedecida a fração de terreno de no mínimo 120 m² por unidade habitacional.\nSomente para lotes com dimensão inferior a 20.000 (vinte mil) m²\nTaxa de ocupação: No caso da área do lote for inferior ao padrão de zoneamento, será admitida taxa de ocupação superior a 50% até o limite de 60%, calculada proporcionalmente à área do lote, exclusivamente para uma habitação unifamiliar.\nTaxa de permeabilidade: Atender regulação específica"
                ]
            },
            'Habitação Institucional': {
                'COEFICIENTE DE APROVEITAMENTO': 1,
                'ALTURA (pavimentos)': 2,
                'PORTE (m²)': None,
                'TAXA DE OCUPAÇÃO MÁXIMA': 0.5,
                'RECUO (m)': 5,
                'TAXA DE PERMEABILIDADE MÍNIMA': 0.25,
                'AFASTAMENTO DAS DIVISAS MÍNIMO (m)': None,
                'LOTE PADRÃO (testada x área)': '12x360',
                'OBSERVACOES': [
                    "Taxa de ocupação: No caso da área do lote for inferior ao padrão de zoneamento, será admitida taxa de ocupação superior a 50% até o limite de 60%, calculada proporcionalmente à área do lote, exclusivamente para uma habitação unifamiliar.",
                    "Taxa de permeabilidade: Atender regulação específica"
                ]
            },
            'Empreendimento inclusivo de habitação de interesse social': {
                'COEFICIENTE DE APROVEITAMENTO': 1,
                'ALTURA (pavimentos)': 2,
                'PORTE (m²)': None,
                'TAXA DE OCUPAÇÃO MÁXIMA': 0.5,
                'RECUO (m)': 5,
                'TAXA DE PERMEABILIDADE MÍNIMA': 0.25,
                'AFASTAMENTO DAS DIVISAS MÍNIMO (m)': None,
                'LOTE PADRÃO (testada x área)': '12x360',
                'OBSERVACOES': [
                    "Taxa de ocupação: No caso da área do lote for inferior ao padrão de zoneamento, será admitida taxa de ocupação superior a 50% até o limite de 60%, calculada proporcionalmente à área do lote, exclusivamente para uma habitação unifamiliar.",
                    "Taxa de permeabilidade: Atender regulação específica"
                ]
            }
        },
        'Usos Não Habitacionais Permitidos': {
            'Comunitário 1': {
                'COEFICIENTE DE APROVEITAMENTO': 1,
                'ALTURA (pavimentos)': 2,
                'PORTE (m²)': 200,
                'TAXA DE OCUPAÇÃO MÁXIMA': 0.5,
                'RECUO (m)': 5,
                'TAXA DE PERMEABILIDADE MÍNIMA': 0.25,
                'AFASTAMENTO DAS DIVISAS MÍNIMO (m)': None,
                'LOTE PADRÃO (testada x área)': '12x360',
                'OBSERVACOES': [
                    "CA: Desde que atendido o porte máximo de 200m²",
                    "A critério do CMU poderá ser concedido alvará de localização para comércio e serviço vicinal, de bairro e comunitário 1, em edificações existentes e portes superior a 200 m² até o máximo de 400 m²."
                ]
            },
            'Comércio e Serviço Vicinal e de Bairro': {
                'COEFICIENTE DE APROVEITAMENTO': 1,
                'ALTURA (pavimentos)': 2,
                'PORTE (m²)': 200,
                'TAXA DE OCUPAÇÃO MÁXIMA': 0.5,
                'RECUO (m)': 5,
                'TAXA DE PERMEABILIDADE MÍNIMA': 0.25,
                'AFASTAMENTO DAS DIVISAS MÍNIMO (m)': None,
                'LOTE PADRÃO (testada x área)': '12x360',
                'OBSERVACOES': [
                    "CA: Desde que atendido o porte máximo de 200m²",
                    "A critério do CMU poderá ser concedido alvará de localização para comércio e serviço vicinal, de bairro e comunitário 1, em edificações existentes e portes superior a 200 m² até o máximo de 400 m²."
                ]
            },
            'Comunitário 2 - Culto Religioso': {
                'COEFICIENTE DE APROVEITAMENTO': 1,
                'ALTURA (pavimentos)': 2,
                'PORTE (m²)': None,
                'TAXA DE OCUPAÇÃO MÁXIMA': 0.5,
                'RECUO (m)': 5,
                'TAXA DE PERMEABILIDADE MÍNIMA': 0.25,
                'AFASTAMENTO DAS DIVISAS MÍNIMO (m)': None,
                'LOTE PADRÃO (testada x área)': '12x360',
                'OBSERVACOES': [
                    "A critério do CMU poderá ser concedido alvará de localização para comércio e serviço vicinal, de bairro e comunitário 1, em edificações existentes e portes superior a 200 m² até o máximo de 400 m²."
                ]
            },
            'Indústria Tipo 1': {
                'COEFICIENTE DE APROVEITAMENTO': None,
                'ALTURA (pavimentos)': None,
                'PORTE (m²)': 200,
                'TAXA DE OCUPAÇÃO MÁXIMA': None,
                'RECUO (m)': None,
                'TAXA DE PERMEABILIDADE MÍNIMA': None,
                'AFASTAMENTO DAS DIVISAS MÍNIMO (m)': None,
                'LOTE PADRÃO (testada x área)': '12x360',
                'OBSERVACOES': [
                    "Somente alvará de licença para localização em edificação existente."
                ]
            }
        },
        'Usos Habitacionais Permissiveis': None,
        'Usos Não Habitacionais Permissiveis': None
    }

def gerar_tabela_zoneamento(data):
    # Preparando uma lista de dados formatados para o DataFrame
    data_list = []
    for uso, categorias in data.items():
        if categorias:
            for categoria, detalhes in categorias.items():
                row = {
                    'Uso': uso,
                    'Categoria': categoria,
                    **detalhes
                }
                data_list.append(row)

    df = pd.DataFrame(data_list)

    # Formatar observações para serem exibidas em uma única célula por linha
    df['OBSERVACOES'] = df['OBSERVACOES'].apply(lambda x: '\n'.join(x) if isinstance(x, list) else x)
    return df

# Utilizando as funções
zn = get_zr2_data()
df_zr2 = gerar_tabela_zoneamento(zn)
df_zr2
# Out:
#                                  Uso  \
# 0      Usos Habitacionais Permitidos
# 1      Usos Habitacionais Permitidos
# 2      Usos Habitacionais Permitidos
# 3      Usos Habitacionais Permitidos
# 4  Usos Não Habitacionais Permitidos
# 5  Usos Não Habitacionais Permitidos
# 6  Usos Não Habitacionais Permitidos
# 7  Usos Não Habitacionais Permitidos
#
#                                            Categoria  \
# 0                              Habitação Unifamiliar
# 1                     Habitação Unifamiliar em Série
# 2                            Habitação Institucional
# 3  Empreendimento inclusivo de habitação de inter...
# 4                                      Comunitário 1
# 5             Comércio e Serviço Vicinal e de Bairro
# 6                    Comunitário 2 - Culto Religioso
# 7                                   Indústria Tipo 1
#
#    COEFICIENTE DE APROVEITAMENTO  ALTURA (pavimentos)  PORTE (m²)  \
# 0                            1.0                  2.0         NaN
# ...

# %%
zr3 = {
    'Usos Habitacionais Permitidos': {
        'Habitação Unifamiliar': {
            'COEFICIENTE DE APROVEITAMENTO': 1,
            'ALTURA (pavimentos)': 3,
            'PORTE (m²)': None,
            'TAXA DE OCUPAÇÃO MÁXIMA': 0.5,
            'RECUO (m)': 5,
            'TAXA DE PERMEABILIDADE MÍNIMA': 0.25,
            'AFASTAMENTO DAS DIVISAS MÍNIMO (m)': None,  # Coloque 'None' ou o valor adequado com base nas observações
            'LOTE PADRÃO (testada x área)': '12x360',
            'OBSERVACOES': [
                "Deverá ser obedecida a fração de terreno de no mínimo 120 m² por unidade habitacional.",
                "Taxa de ocupação: No caso da área do lote for inferior ao padrão de zoneamento, será admitida taxa de ocupação superior a 50% até o limite de 60%, calculada proporcionalmente à área do lote, exclusivamente para uma habitação unifamiliar.",
                "Atender regulamentação específica.",
                "Até 3 pavimentos com o máximo de 10 metros de altura, afastamento das divisas facultado."
            ]
        },
        'Habitação Unifamiliar em Série': {
            'COEFICIENTE DE APROVEITAMENTO': 1,
            'ALTURA (pavimentos)': 3,
            'PORTE (m²)': None,
            'TAXA DE OCUPAÇÃO MÁXIMA': 0.5,
            'RECUO (m)': 5,
            'TAXA DE PERMEABILIDADE MÍNIMA': 0.25,
            'AFASTAMENTO DAS DIVISAS MÍNIMO (m)': None,  # Coloque 'None' ou o valor adequado com base nas observações
            'LOTE PADRÃO (testada x área)': '12x360',
            'OBSERVACOES': [
                "Deverá ser obedecida a fração de terreno de no mínimo 120 m² por unidade habitacional.",
                "Taxa de ocupação: No caso da área do lote for inferior ao padrão de zoneamento, será admitida taxa de ocupação superior a 50% até o limite de 60%, calculada proporcionalmente à área do lote, exclusivamente para uma habitação unifamiliar.",
                "Atender regulamentação específica.",
                "Até 3 pavimentos com o máximo de 10 metros de altura, afastamento das divisas facultado."
            ]
        },
        'Habitação Coletiva': {
            'COEFICIENTE DE APROVEITAMENTO': 1,
            'ALTURA (pavimentos)': 3,
            'PORTE (m²)': None,
            'TAXA DE OCUPAÇÃO MÁXIMA': 0.5,
            'RECUO (m)': 5,
            'TAXA DE PERMEABILIDADE MÍNIMA': 0.25,
            'AFASTAMENTO DAS DIVISAS MÍNIMO (m)': None,  # Coloque 'None' ou o valor adequado com base nas observações
            'LOTE PADRÃO (testada x área)': '12x360',
            'OBSERVACOES': [
                "Deverá ser obedecida a fração de terreno de no mínimo 120 m² por unidade habitacional.",
                "Taxa de ocupação: No caso da área do lote for inferior ao padrão de zoneamento, será admitida taxa de ocupação superior a 50% até o limite de 60%, calculada proporcionalmente à área do lote, exclusivamente para uma habitação unifamiliar.",
                "Atender regulamentação específica.",
                "Até 3 pavimentos com o máximo de 10 metros de altura, afastamento das divisas facultado."
            ]
        },
        'Habitação Institucional': {
            'COEFICIENTE DE APROVEITAMENTO': 1,
            'ALTURA (pavimentos)': 3,
            'PORTE (m²)': None,
            'TAXA DE OCUPAÇÃO MÁXIMA': 0.5,
            'RECUO (m)': 5,
            'TAXA DE PERMEABILIDADE MÍNIMA': 0.25,
            'AFASTAMENTO DAS DIVISAS MÍNIMO (m)': 2.50,  # Coloque 'None' ou o valor adequado com base nas observações
            'LOTE PADRÃO (testada x área)': '12x360',
            'OBSERVACOES': [
                "Deverá ser obedecida a fração de terreno de no mínimo 120 m² por unidade habitacional.",
                "Taxa de ocupação: No caso da área do lote for inferior ao padrão de zoneamento, será admitida taxa de ocupação superior a 50% até o limite de 60%, calculada proporcionalmente à área do lote, exclusivamente para uma habitação unifamiliar.",
                "Atender regulamentação específica.",
                "Até 3 pavimentos com o máximo de 10 metros de altura, afastamento das divisas facultado."
            ]
        },
        'Habitação Transitória': {
            'COEFICIENTE DE APROVEITAMENTO': 1,
            'ALTURA (pavimentos)': 3,
            'PORTE (m²)': None,
            'TAXA DE OCUPAÇÃO MÁXIMA': 0.5,
            'RECUO (m)': 5,
            'TAXA DE PERMEABILIDADE MÍNIMA': 0.25,
            'AFASTAMENTO DAS DIVISAS MÍNIMO (m)': 2.50,  # Coloque 'None' ou o valor adequado com base nas observações
            'LOTE PADRÃO (testada x área)': '12x360',
            'OBSERVACOES': [
                "Deverá ser obedecida a fração de terreno de no mínimo 120 m² por unidade habitacional.",
                "Taxa de ocupação: No caso da área do lote for inferior ao padrão de zoneamento, será admitida taxa de ocupação superior a 50% até o limite de 60%, calculada proporcionalmente à área do lote, exclusivamente para uma habitação unifamiliar.",
                "Atender regulamentação específica.",
                "Até 3 pavimentos com o máximo de 10 metros de altura, afastamento das divisas facultado."
            ]
        },
        'Empreendimento Inclusivo de habitação de interesse social': {
            'COEFICIENTE DE APROVEITAMENTO': 1,
            'ALTURA (pavimentos)': 3,
            'PORTE (m²)': None,
            'TAXA DE OCUPAÇÃO MÁXIMA': 0.5,
            'RECUO (m)': 5,
            'TAXA DE PERMEABILIDADE MÍNIMA': 0.25,
            'AFASTAMENTO DAS DIVISAS MÍNIMO (m)': 2.50,  # Coloque 'None' ou o valor adequado com base nas observações
            'LOTE PADRÃO (testada x área)': '12x360',
            'OBSERVACOES': [
                "Deverá ser obedecida a fração de terreno de no mínimo 120 m² por unidade habitacional.",
                "Taxa de ocupação: No caso da área do lote for inferior ao padrão de zoneamento, será admitida taxa de ocupação superior a 50% até o limite de 60%, calculada proporcionalmente à área do lote, exclusivamente para uma habitação unifamiliar.",
                "Atender regulamentação específica.",
                "Até 3 pavimentos com o máximo de 10 metros de altura, afastamento das divisas facultado."
            ]
        },
    },
    'Usos Não Habitacionais Permitidos': {
        'Comunitário 1': {
            'COEFICIENTE DE APROVEITAMENTO': 1,
            'ALTURA (pavimentos)': 2,
            'PORTE (m²)': 200,
            'TAXA DE OCUPAÇÃO MÁXIMA': 0.5,
            'RECUO (m)': 5,
            'TAXA DE PERMEABILIDADE MÍNIMA': 0.25,
            'AFASTAMENTO DAS DIVISAS MÍNIMO (m)': None,  # Coloque 'None' ou o valor adequado com base nas observações
            'LOTE PADRÃO (testada x área)': '12x360',
            'OBSERVACOES': [
                "A critério do CMU, poderá ser concedido alvará de localização para Comércio e Serviço Vicinal, de Bairro e Comunitário 1, em edificações existentes e porte superior a 200 (duzentos) m², até o máximo de 400 (quatrocentos) m²",
                "Taxa de ocupação: Atendido o porte máximo de 200 (duzentos) m².",
                "Atender regulamentação específica."
            ]
        },
        'Comunitário 2 - Saúde': {
            'COEFICIENTE DE APROVEITAMENTO': 1,
            'ALTURA (pavimentos)': 2,
            'PORTE (m²)': 200,
            'TAXA DE OCUPAÇÃO MÁXIMA': 0.5,
            'RECUO (m)': 5,
            'TAXA DE PERMEABILIDADE MÍNIMA': 0.25,
            'AFASTAMENTO DAS DIVISAS MÍNIMO (m)': None,  # Coloque 'None' ou o valor adequado com base nas observações
            'LOTE PADRÃO (testada x área)': '12x360',
            'OBSERVACOES': [
                "A critério do CMU, poderá ser concedido alvará de localização para Comércio e Serviço Vicinal, de Bairro e Comunitário 1, em edificações existentes e porte superior a 200 (duzentos) m², até o máximo de 400 (quatrocentos) m²",
                "Taxa de ocupação: Atendido o porte máximo de 200 (duzentos) m².",
                "Atender regulamentação específica."
            ]
        },
        'Comércio e Serviço Vicinal e de Bairro': {
            'COEFICIENTE DE APROVEITAMENTO': 1,
            'ALTURA (pavimentos)': 2,
            'PORTE (m²)': 200,
            'TAXA DE OCUPAÇÃO MÁXIMA': 0.5,
            'RECUO (m)': 5,
            'TAXA DE PERMEABILIDADE MÍNIMA': 0.25,
            'AFASTAMENTO DAS DIVISAS MÍNIMO (m)': None,  # Coloque 'None' ou o valor adequado com base nas observações
            'LOTE PADRÃO (testada x área)': '12x360',
            'OBSERVACOES': [
                "A critério do CMU, poderá ser concedido alvará de localização para Comércio e Serviço Vicinal, de Bairro e Comunitário 1, em edificações existentes e porte superior a 200 (duzentos) m², até o máximo de 400 (quatrocentos) m²",
                "Taxa de ocupação: Atendido o porte máximo de 200 (duzentos) m².",
                "Atender regulamentação específica."
            ]
        },
        'Comunitário 2 - Culto Religioso': {
            'COEFICIENTE DE APROVEITAMENTO': 1,
            'ALTURA (pavimentos)': 2,
            'PORTE (m²)': None,
            'TAXA DE OCUPAÇÃO MÁXIMA': 0.5,
            'RECUO (m)': 5,
            'TAXA DE PERMEABILIDADE MÍNIMA': 0.25,
            'AFASTAMENTO DAS DIVISAS MÍNIMO (m)': None,  # Coloque 'None' ou o valor adequado com base nas observações
            'LOTE PADRÃO (testada x área)': '12x360',
            'OBSERVACOES': [
                "Taxa de ocupação: Atendido o porte máximo de 200 (duzentos) m²."
            ]
        },
        'Indústria do Tipo 1': {
            'COEFICIENTE DE APROVEITAMENTO': None,
            'ALTURA (pavimentos)': None,
            'PORTE (m²)': 200,
            'TAXA DE OCUPAÇÃO MÁXIMA': None,
            'RECUO (m)': None,
            'TAXA DE PERMEABILIDADE MÍNIMA': None,
            'AFASTAMENTO DAS DIVISAS MÍNIMO (m)': None,  # Coloque 'None' ou o valor adequado com base nas observações
            'LOTE PADRÃO (testada x área)': '12x360',
            'OBSERVACOES': [
                "Somente alvará de localização em edificação existente."
            ]
        },
        # Adicionar outros usos não permitidos habitacionais conforme necessário
    },
    'Usos Habitacionais Permissiveis': None,
    'Usos Não Habitacionais Permissiveis': None
}

def get_zr3_data():
    return zr3

def gerar_tabela_zoneamento(data):
    # Preparando uma lista de dados formatados para o DataFrame
    data_list = []
    for uso, categorias in data.items():
        if categorias:
            for categoria, detalhes in categorias.items():
                row = {
                    'Uso': uso,
                    'Categoria': categoria,
                    **detalhes
                }
                data_list.append(row)

    df = pd.DataFrame(data_list)

    # Formatar observações para serem exibidas em uma única célula por linha
    df['OBSERVACOES'] = df['OBSERVACOES'].apply(lambda x: '\n'.join(x) if isinstance(x, list) else x)
    return df

# Utilizando as funções
zn = get_zr3_data()
df_zr2 = gerar_tabela_zoneamento(zn)
df_zr2
# Out:
#                                   Uso  \
# 0       Usos Habitacionais Permitidos
# 1       Usos Habitacionais Permitidos
# 2       Usos Habitacionais Permitidos
# 3       Usos Habitacionais Permitidos
# 4       Usos Habitacionais Permitidos
# 5       Usos Habitacionais Permitidos
# 6   Usos Não Habitacionais Permitidos
# 7   Usos Não Habitacionais Permitidos
# 8   Usos Não Habitacionais Permitidos
# 9   Usos Não Habitacionais Permitidos
# 10  Usos Não Habitacionais Permitidos
#
#                                             Categoria  \
# 0                               Habitação Unifamiliar
# 1                      Habitação Unifamiliar em Série
# 2                                  Habitação Coletiva
# 3                             Habitação Institucional
# 4                               Habitação Transitória
# 5   Empreendimento Inclusivo de habitação de inter...
# 6                                       Comunitário 1
# 7                               Comunitário 2 - Saúde
# ...
